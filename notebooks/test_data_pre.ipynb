# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from src.config import PROCESSED_DATA_DIR, INTERIM_DATA_DIR

input_test_path: Path = INTERIM_DATA_DIR / "testset.csv"

df = pd.read_csv(str(input_test_path), index_col='id')
df.head()
# Out:
# 2024-10-12 21:36:42.308 | INFO     | dbos.config:<module>:14 - PROJ_ROOT path is: G:\Work\DS\dont-bet-on-sports
#               season  event_date        tm_nano  tm_market   tm_name tm_alias  \
# id
# 201910200nyg    2019  2019-10-20  n8CuHV9wbYCqF   New York    Giants      NYG
# 201910200gnb    2019  2019-10-20  D5QY6bOxfn8ZL  Green Bay   Packers       GB
# 201910200oti    2019  2019-10-20  ltMyRE3yvVUaw  Tennessee    Titans      TEN
# 201910200chi    2019  2019-10-20  1vVmWGzUZ1rea    Chicago     Bears      CHI
# 201910200sea    2019  2019-10-20  4M8AK5p0WXs1N    Seattle  Seahawks      SEA
#
#                    opp_nano   opp_market   opp_name opp_alias  ...  \
# id                                                             ...
# 201910200nyg  GJizlkzQFaqGA      Arizona  Cardinals       ARI  ...
# 201910200gnb  LZoDld8s63xUs    Las Vegas    Raiders        LV  ...
# 201910200oti  SjaMbkmeizJD4  Los Angeles   Chargers       LAC  ...
# ...

# %%
from src.features import prepare_data

df = prepare_data(df)
# Out:
# 2024-10-12 21:36:43.106 | INFO     | dbos.features:prepare_data:94 - <bound method DataFrame.to_string of Empty DataFrame
# Columns: [games, first_downs, fourth_down_att, fourth_down_conv, fourth_down_conv_pct, fumbles, fumbles_lost, net_pass_yds, pass_att, pass_cmp, pass_int, pass_tds, pass_yds, passer_rating, penalties, penalty_yds, rush_att, rush_tds, rush_yds, third_down_att, third_down_conv, third_down_conv_pct, time_of_possession, times_sacked, total_yds, turnovers, yds_sacked_for]
# Index: []
#
# [0 rows x 27 columns]>
# 2024-10-12 21:36:43.113 | INFO     | dbos.features:prepare_data:97 - Created STATS

# %%
processed_test_path: Path = PROCESSED_DATA_DIR / "testset.csv"
df.to_csv(processed_test_path)
